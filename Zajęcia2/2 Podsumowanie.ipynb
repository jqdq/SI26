# %% [markdown]
# Sprawdz czy wiesz:
# 1. Czy wiesz jak stworzyc dowolny klasyfikator z wykorzystaniem SVM? Dowolny oznacza, że potrafisz kontrolować typ kernala oraz wartość parametru c.
# 2. Czy potrafisz interpretować wykresy, które porównują wartości skuteczności dla różnych klasyfikatorów SVM?
# 3. Czy wiesz jak stworzyc klasyfikator z wykorzystaniem GaussianNB?
# 4. Czy wiesz jak stworzyc dowolny klasyfikator z wykorzystaniem drzew decyzyjnych? Dowolny oznacza, że potrafisz kontrolować wartość parametru max_depth.
#
#
# Zadania:
# Dla następujących zbiorów danych:
# 1. "/usr/share/SI/breast-cancer.csv"
# 2. "/usr/share/SI/healthcare-dataset-stroke-data.csv"
# 3. "/usr/share/SI/Raisin_Dataset.csv"
#
# sprawdź, jaki algorytm najlepiej poradzi sobie z detekcją klasy decyzyjnej. Dla SVM sprawdź różne kernele i wartości wspólczynnika C, dla drzew decyzyjnych sprawdz równe wartości max_depth. Wykorzystaj również klasyfikator naiwnego Bayesa.
