# %% [markdown]
# Sprawdz czy wiesz:
# 1. Czy wiesz jak stworzyc model regresji?
# 2. Czy potrafisz interpretować wykresy oraz wyniki modelu regresji?
# 3. Czy wiesz jak interpretować wyniki uzyskane przez algorytm PCA?
# 4. Czy wiesz jak stworzyc dowolny klasyfikator (kNN, SVM, drzewa...) z wykorzystaniem algorytmu PCA?
#
# Zadanie 1:
# Dla następujących zbiorów danych (w nawiasach podano zmienna decyzyjną):
# 1. "/usr/share/SI/lending_club_loan_dataset.csv" (annual_inc)
# 2. "/usr/share/SI/winequality-red.csv" (alcohol)
# 3. "/usr/share/SI/insurance.csv" (charges)
#
# swtórz modele regresji i zinterpretuj uzyskane wyniki.
#
# Zadanie 2:
# Dla następujących zbiorów danych:
#
# 1. "/usr/share/SI/breast-cancer.csv"
# 2. "/usr/share/SI/healthcare-dataset-stroke-data.csv"
# 3. "/usr/share/SI/Raisin_Dataset.csv"
#
# sprawdź, jaki algorytm najlepiej poradzi sobie z detekcją klasy decyzyjnej. Wykorzystaj dowolny algorytm lub algorytmy klasyfikacyjne oraz algorytm PCA do redukcji danych.
