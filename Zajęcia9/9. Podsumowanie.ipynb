# %% [markdown]
# Sprawdz czy wiesz:
#
# 1. Jak stosować i zmieniać wartość learning rate i jak iterpretować wyniki?
# 2. Jak stosować i zmieniać wartość dropout i jak iterpretować wyniki?
# 3. Jak stosować i zmieniać współczynnik regularyzacji i jak iterpretować wyniki?
#
#
# Zadanie1 :
#
# Dla dowolnych datasetów wykorzystywanych na zajęciach stwórz modele:
# 1. "Czysty"
# 2. z dropoutem
# 3. z regularyzacją
#
# sprawdz i oceń jak wprowadzenie dodatkowych elementów wpłyneło na działanie sieci. Czy udało się osiągnąć wyższą skuteczność, czy zmniejszyć przeuczenie?
#
# Zadanie 2:
# Dla dowolnych datasetów wykorzystywanych na zajęciach stwórz modele z różnymi wartościami learning rate. Zinterpretuj wyniki. Jaka wartość learning rate okazała się optymalna?
