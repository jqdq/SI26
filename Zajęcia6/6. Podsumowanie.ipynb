# %% [markdown]
# Sprawdz czy wiesz:
#
# 1. Jak stworzyć prostą sieć neuronową?
# 2. Jak interpretować rezultaty uczenia sieci?
# 3. Czy wiesz jak powinna być zbudowana sieć: kolejnośc warstw, liczba neuronów w warstwach.
#
#
#
# Zadania:
# Dla następujących zbiorów danych (te same jak na zajęciach 2):
# 1. "/usr/share/SI/breast-cancer.csv"
# 2. "/usr/share/SI/healthcare-dataset-stroke-data.csv"
# 3. "/usr/share/SI/Raisin_Dataset.csv"
#
# zbuduj kilka sieci neuronowych, których zadaniem będzie przewidzieć zmienne decyzyjne. Porównaj uzyskane wyniki sieci z wynikami uzyskanymi na zajęciach drugich.
