# %% [markdown]
# Sprawdz czy wiesz:
#
# 1. Jak pogrupować dane za pomocą algorytmu kmeans (dla dowolnej liczby klastrów)?
# 2. Jak pogrupować dane za pomocą algorytmu AC (dla dowolnej liczby klastrów)?
# 3. Jak pogrupować dane za pomocą algorytmu DBSCAN?
#
#
# Zadanie:
# Dla następujących zbiorów danych (w nawiasach podano zmienna decyzyjną, którą należy usunąć):
#
# 1. "/usr/share/SI/lending_club_loan_dataset.csv" (annual_inc)
# 2. "/usr/share/SI/winequality-red.csv" (alcohol)
# 3. "/usr/share/SI/insurance.csv" (charges)
#
# podziel dane na grupy z pomocą trzech poznanych algorytmów. Dobierz optymalną liczbę grup.
