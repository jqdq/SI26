# %% [markdown]
# Sprawdz czy wiesz:
# 1. Czy wiesz jak stworzyc model regresji?
# 2. Czy potrafisz interpretować wykresy uczenia oraz wyniki modelu regresji?
#
# Zadanie:
# Dla następujących zbiorów danych (w nawiasach podano zmienna decyzyjną):
# 1. "/usr/share/SI/lending_club_loan_dataset.csv" (annual_inc)
# 2. "/usr/share/SI/winequality-red.csv" (alcohol)
# 3. "/usr/share/SI/insurance.csv" (charges)
#
# swtórz modele regresji i zinterpretuj uzyskane wyniki. Spróbuj porównać ze sobą różne modele sieci różniące się wielkością.
