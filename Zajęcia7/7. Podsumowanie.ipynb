# %% [markdown]
# Sprawdz czy wiesz:
#
# 1. Czy wiesz jak zastosować early stopping?
# 2. Kiedy stosować jako ostatnią warstwę sigmoid lub softmax?
# 3. Kiedy stosować binary a kiedy categorical crossentropy?
#
# Zadanie:
# Dla następujących zbiorów danych:
#
# 1. "/usr/share/SI/Iris.csv"
# 2. "/usr/share/SI/winequality-red.csv"
# 3. "/usr/share/SI/student.csv"
#
# sprawdź, jaki algorytm najlepiej poradzi sobie z detekcją klasy decyzyjnej. Stwórz kilka modeli sieci, wykorzystaj early stopping.
