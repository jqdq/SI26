# %% [markdown]
# Sprawdz czy wiesz:
# 1. Jak podzielić zbiór danych na dane treningowe i testowe?
# 2. Jak zamienić dane tekstowe na liczbowe?
# 3. Czy wiesz jak stworzyc dowolny klasyfikator z wykorzystaniem kNN? Dowolny oznacza, ze potrafisz kontorlować liczbę sąsiadów.
# 4. Czy potrafisz interpretować wykresy, które porównują wartości skuteczności dla różnych klasyfikatorów kNN?
# 5. Czy potrafisz przeskalować dane wykorzystująć normalizację lub standaryzację?
# 6. Czy potrafisz wstępnie oczyścić dane?
#
# Zadanie 1:
#
# Oczyść dane ze zbioru: "/usr/share/SI/lending_club_loan_dataset.csv".
# Należy:
# 1. usunąć niepotrzebne kolumny: "id","purpose","term", "last_major_derog_none"
# 2. zamienić dane tekstowe na liczbowe: 'home_ownership', 'grade'
# 3. zamienić NaN na -1 w kolumnach: "grade", "dti", "home_ownership"
# 4. kolumnę "annual_inc" podzielić przez 1000
#
# Zadania 2:
# Dla następujących zbiorów danych:
# 1. "/usr/share/SI/breast-cancer.csv"
# 2. "/usr/share/SI/Iris.csv"
# 3. "/usr/share/SI/Raisin_Dataset.csv"
#
# sprawdź, jaki algorytm najlepiej poradzi sobie z detekcją klasy decyzyjnej dla różnej liczby sąsiadów.
